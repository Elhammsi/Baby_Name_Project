# %% [markdown]
# #   Importing & Merging many files (Baby Names Dataset)

# %% [markdown]
# ## Importing one File & Understanding the Data Structure

# %%
import pandas as pd

# %%
pd.read_csv("yob1880.txt")
# Out:
#            Mary  F  7065
# 0          Anna  F  2604
# 1          Emma  F  2003
# 2     Elizabeth  F  1939
# 3        Minnie  F  1746
# 4      Margaret  F  1578
# ...         ... ..   ...
# 1994     Woodie  M     5
# 1995     Worthy  M     5
# 1996     Wright  M     5
# 1997       York  M     5
# 1998  Zachariah  M     5
#
# [1999 rows x 3 columns]

# %% [markdown]
# **the dataset does not have headear**

# %%
df = pd.read_csv("yob1880.txt", header = None, names = ["Name", "Gender", "Count"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2000 non-null   object
#  1   Gender  2000 non-null   object
#  2   Count   2000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# ## Importing & merging many files (easy case)

# %% [markdown]
# **all datasets ate seprate so we have to merge all of them**

# %%
df_1880 = pd.read_csv("yob1880.txt", header = None, names = ["Name", "Gender", "Count"])
df_1880
# Out:
#            Name Gender  Count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# ...         ...    ...    ...
# 1995     Woodie      M      5
# 1996     Worthy      M      5
# 1997     Wright      M      5
# 1998       York      M      5
# 1999  Zachariah      M      5
#
# [2000 rows x 3 columns]

# %%
df_1881 = pd.read_csv("yob1881.txt", header = None, names = ["Name", "Gender", "Count"])
df_1881
# Out:
#            Name Gender  Count
# 0          Mary      F   6919
# 1          Anna      F   2698
# 2          Emma      F   2034
# 3     Elizabeth      F   1852
# 4      Margaret      F   1658
# ...         ...    ...    ...
# 1929     Wiliam      M      5
# 1930     Wilton      M      5
# 1931       Wing      M      5
# 1932       Wood      M      5
# 1933     Wright      M      5
#
# [1934 rows x 3 columns]

# %%
pd.concat(objs = [df_1880, df_1881], axis = 0, keys = [1880, 1881], names = ["Year"])
# Out:
#                 Name Gender  Count
# Year
# 1880 0          Mary      F   7065
#      1          Anna      F   2604
#      2          Emma      F   2003
#      3     Elizabeth      F   1939
#      4        Minnie      F   1746
# ...              ...    ...    ...
# 1881 1929     Wiliam      M      5
#      1930     Wilton      M      5
#      1931       Wing      M      5
#      1932       Wood      M      5
#      1933     Wright      M      5
#
# [3934 rows x 3 columns]

# %% [markdown]
# **we have doplicate index and it is not clear that which row belongs to each year**

# %%
pd.concat(objs = [df_1880, df_1881], axis = 0, keys = [1880, 1881],
          names = ["Year"]).droplevel(-1).reset_index()
# Out:
#       Year       Name Gender  Count
# 0     1880       Mary      F   7065
# 1     1880       Anna      F   2604
# 2     1880       Emma      F   2003
# 3     1880  Elizabeth      F   1939
# 4     1880     Minnie      F   1746
# ...    ...        ...    ...    ...
# 3929  1881     Wiliam      M      5
# 3930  1881     Wilton      M      5
# 3931  1881       Wing      M      5
# 3932  1881       Wood      M      5
# 3933  1881     Wright      M      5
#
# [3934 rows x 4 columns]

# %%
pd.read_csv("yob{}.txt".format(1880), header = None, names = ["Name", "Gender", "Count"])
# Out:
#            Name Gender  Count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# ...         ...    ...    ...
# 1995     Woodie      M      5
# 1996     Worthy      M      5
# 1997     Wright      M      5
# 1998       York      M      5
# 1999  Zachariah      M      5
#
# [2000 rows x 3 columns]

# %%
years = list(range(1880, 2024))
years
# Out:
# [1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
# ...

# %%
dataframes = []
for year in years:
    data = pd.read_csv("yob{}.txt".format(year), header = None, 
                       names = ["Name", "Gender", "Count"])
    dataframes.append(data)

# %%
dataframes
# Out:
# [           Name Gender  Count
#  0          Mary      F   7065
#  1          Anna      F   2604
#  2          Emma      F   2003
#  3     Elizabeth      F   1939
#  4        Minnie      F   1746
#  ...         ...    ...    ...
#  1995     Woodie      M      5
#  1996     Worthy      M      5
#  1997     Wright      M      5
#  1998       York      M      5
#  1999  Zachariah      M      5
#
#  [2000 rows x 3 columns],
#             Name Gender  Count
#  0          Mary      F   6919
#  1          Anna      F   2698
#  2          Emma      F   2034
#  3     Elizabeth      F   1852
#  4      Margaret      F   1658
#  ...         ...    ...    ...
#  1929     Wiliam      M      5
#  1930     Wilton      M      5
#  1931       Wing      M      5
#  1932       Wood      M      5
#  1933     Wright      M      5
#
#  [1934 rows x 3 columns],
#             Name Gender  Count
#  0          Mary      F   8148
#  1          Anna      F   3143
#  2          Emma      F   2303
# ...

# %%
len(dataframes)
# Out:
# 144

# %%
df = pd.concat(dataframes,  axis = 0, keys = years, names = ["Year"]).droplevel(-1).reset_index()

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [2117219 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117219 entries, 0 to 2117218
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Name    object
#  2   Gender  object
#  3   Count   int64
# dtypes: int64(2), object(2)
# memory usage: 64.6+ MB

# %%
df.to_csv("us_baby_names.csv", index = False)

# %%
pd.read_csv("us_baby_names.csv")
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [2117219 rows x 4 columns]

# %% [markdown]
#  #  Explanatory Data Analysis & Advanced Visualization (Baby Names Dataset)

# %% [markdown]
# ## First Inspection: The most popular Names  in 2023

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("us_baby_names.csv")

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [2117219 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117219 entries, 0 to 2117218
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Name    object
#  2   Gender  object
#  3   Count   int64
# dtypes: int64(2), object(2)
# memory usage: 64.6+ MB

# %%
df.nunique()
# Out:
# Year         144
# Name      103564
# Gender         2
# Count      13905
# dtype: int64

# %%
df.Gender = df.Gender.astype("category")# for saving more memory

# %%
names_2023 = df[df.Year == 2023].copy()
names_2023
# Out:
#          Year       Name Gender  Count
# 2085537  2023     Olivia      F  15270
# 2085538  2023       Emma      F  13527
# 2085539  2023  Charlotte      F  12596
# 2085540  2023     Amelia      F  12311
# 2085541  2023     Sophia      F  11944
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [31682 rows x 4 columns]

# %%
names_2023[names_2023.Gender == "F"].nlargest(10, "Count")#10 most popular name in 2023 for femail
# Out:
#          Year       Name Gender  Count
# 2085537  2023     Olivia      F  15270
# 2085538  2023       Emma      F  13527
# 2085539  2023  Charlotte      F  12596
# 2085540  2023     Amelia      F  12311
# 2085541  2023     Sophia      F  11944
# 2085542  2023        Mia      F  11359
# 2085543  2023   Isabella      F  10808
# 2085544  2023        Ava      F   9682
# 2085545  2023     Evelyn      F   9082
# 2085546  2023       Luna      F   7811

# %%
def most_pop(year, gender, n):
    return df[(df.Year == year) & (df.Gender == gender)].nlargest(n, "Count")

# %%
most_pop(2023, "F", 10)
# Out:
#          Year       Name Gender  Count
# 2085537  2023     Olivia      F  15270
# 2085538  2023       Emma      F  13527
# 2085539  2023  Charlotte      F  12596
# 2085540  2023     Amelia      F  12311
# 2085541  2023     Sophia      F  11944
# 2085542  2023        Mia      F  11359
# 2085543  2023   Isabella      F  10808
# 2085544  2023        Ava      F   9682
# 2085545  2023     Evelyn      F   9082
# 2085546  2023       Luna      F   7811

# %%
most_pop(2023, "M", 10)
# Out:
#          Year      Name Gender  Count
# 2103070  2023      Liam      M  20802
# 2103071  2023      Noah      M  18995
# 2103072  2023    Oliver      M  14741
# 2103073  2023     James      M  11670
# 2103074  2023    Elijah      M  11452
# 2103075  2023     Mateo      M  11229
# 2103076  2023  Theodore      M  11041
# 2103077  2023     Henry      M  10941
# 2103078  2023     Lucas      M  10842
# 2103079  2023   William      M  10598

# %% [markdown]
# ## Most popular Names in  (1880 - 2023)

# %%
f_2023 = most_pop(2023, "F", 20)
f_2023
# Out:
#          Year       Name Gender  Count
# 2085537  2023     Olivia      F  15270
# 2085538  2023       Emma      F  13527
# 2085539  2023  Charlotte      F  12596
# 2085540  2023     Amelia      F  12311
# 2085541  2023     Sophia      F  11944
# 2085542  2023        Mia      F  11359
# 2085543  2023   Isabella      F  10808
# 2085544  2023        Ava      F   9682
# 2085545  2023     Evelyn      F   9082
# 2085546  2023       Luna      F   7811
# 2085547  2023     Harper      F   7769
# 2085548  2023      Sofia      F   7641
# 2085549  2023     Camila      F   7565
# 2085550  2023    Eleanor      F   6739
# 2085551  2023  Elizabeth      F   6566
# 2085552  2023     Violet      F   6342
# 2085553  2023   Scarlett      F   6288
# 2085554  2023      Emily      F   6154
# 2085555  2023      Hazel      F   6154
# 2085556  2023       Lily      F   6146

# %%
f_1880 = most_pop(1880, "F", 20)
f_1880
# Out:
#     Year       Name Gender  Count
# 0   1880       Mary      F   7065
# 1   1880       Anna      F   2604
# 2   1880       Emma      F   2003
# 3   1880  Elizabeth      F   1939
# 4   1880     Minnie      F   1746
# 5   1880   Margaret      F   1578
# 6   1880        Ida      F   1472
# 7   1880      Alice      F   1414
# 8   1880     Bertha      F   1320
# 9   1880      Sarah      F   1288
# 10  1880      Annie      F   1258
# 11  1880      Clara      F   1226
# 12  1880       Ella      F   1156
# 13  1880   Florence      F   1063
# 14  1880       Cora      F   1045
# 15  1880     Martha      F   1040
# 16  1880      Laura      F   1012
# 17  1880     Nellie      F    995
# 18  1880      Grace      F    982
# 19  1880     Carrie      F    949

# %%
f_2023[["Name", "Count"]].merge(f_1880[["Name", "Count"]], how = "inner", on = "Name")
# Out:
#         Name  Count_x  Count_y
# 0       Emma    13527     2003
# 1  Elizabeth     6566     1939

# %%
f_evergreen = f_2023[["Name", "Count"]].merge(f_1880[["Name", "Count"]], how = "inner", on = "Name", 
                           suffixes=("_2023", "_1880"))
f_evergreen
# Out:
#         Name  Count_2023  Count_1880
# 0       Emma       13527        2003
# 1  Elizabeth        6566        1939

# %%
m_2023 = most_pop(2023, "M", 20)
m_2023
# Out:
#          Year       Name Gender  Count
# 2103070  2023       Liam      M  20802
# 2103071  2023       Noah      M  18995
# 2103072  2023     Oliver      M  14741
# 2103073  2023      James      M  11670
# 2103074  2023     Elijah      M  11452
# 2103075  2023      Mateo      M  11229
# 2103076  2023   Theodore      M  11041
# 2103077  2023      Henry      M  10941
# 2103078  2023      Lucas      M  10842
# 2103079  2023    William      M  10598
# 2103080  2023   Benjamin      M  10172
# 2103081  2023       Levi      M   9347
# 2103082  2023  Sebastian      M   8865
# 2103083  2023       Jack      M   8683
# 2103084  2023       Ezra      M   8437
# 2103085  2023    Michael      M   8383
# 2103086  2023     Daniel      M   8356
# 2103087  2023        Leo      M   8120
# 2103088  2023       Owen      M   7985
# 2103089  2023     Samuel      M   7973

# %%
m_1880 = most_pop(1880, "M", 20)
m_1880
# Out:
#      Year     Name Gender  Count
# 942  1880     John      M   9655
# 943  1880  William      M   9532
# 944  1880    James      M   5927
# 945  1880  Charles      M   5348
# 946  1880   George      M   5126
# 947  1880    Frank      M   3242
# 948  1880   Joseph      M   2632
# 949  1880   Thomas      M   2534
# 950  1880    Henry      M   2444
# 951  1880   Robert      M   2415
# 952  1880   Edward      M   2364
# 953  1880    Harry      M   2152
# 954  1880   Walter      M   1755
# 955  1880   Arthur      M   1599
# 956  1880     Fred      M   1569
# 957  1880   Albert      M   1493
# 958  1880   Samuel      M   1024
# 959  1880    David      M    869
# 960  1880    Louis      M    828
# 961  1880      Joe      M    731

# %%
m_evergreen = m_2023[["Name", "Count"]].merge(m_1880[["Name", "Count"]], how = "inner", on = "Name", 
                                              suffixes=("_2023", "_1880"))
m_evergreen
# Out:
#       Name  Count_2023  Count_1880
# 0    James       11670        5927
# 1    Henry       10941        2444
# 2  William       10598        9532
# 3   Samuel        7973        1024

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## General Trends over time (1880 - 2018)

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [2117219 rows x 4 columns]

# %%
babies_per_year = df.groupby("Year").Count.sum()

# %%
babies_per_year
# Out:
# Year
# 1880     201484
# 1881     192688
# 1882     221533
# 1883     216945
# 1884     243461
#          ...
# 2019    3468791
# 2020    3337845
# 2021    3384687
# 2022    3378611
# 2023    3297246
# Name: Count, Length: 144, dtype: int64

# %%
babies_per_year.plot(kind = "bar", y= "Count", figsize = (15, 10), fontsize = 15)
plt.xticks(ticks = (range(0, len(babies_per_year), 5)), labels =  range(1880, 2024, 5))
plt.title("Registered Babies per Year", fontsize = 20)
plt.show()

# %% [markdown]
# **we can see that the number of baby and registered babay have icncreased over time. we want to see the diffrent name per year**

# %%
diff_names = df.groupby("Year").Name.count()
diff_names
# Out:
# Year
# 1880     2000
# 1881     1934
# 1882     2127
# 1883     2084
# 1884     2297
#         ...
# 2019    32126
# 2020    31550
# 2021    31729
# 2022    32042
# 2023    31682
# Name: Name, Length: 144, dtype: int64

# %%
diff_names.plot(kind = "bar", figsize = (15, 10), fontsize = 15)
plt.xticks(ticks = (range(0, len(diff_names), 5)), labels =  range(1880, 2024, 5))
plt.title("Unique Names per Year", fontsize = 20)
plt.show()

# %% [markdown]
# **the name are getting more diverse overtime**

# %% [markdown]
# ## Creating the Features "Popularity" and "Rank"

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2117214  2023      Zyell      M      5
# 2117215  2023       Zyen      M      5
# 2117216  2023     Zymirr      M      5
# 2117217  2023     Zyquan      M      5
# 2117218  2023      Zyrin      M      5
#
# [2117219 rows x 4 columns]

# %% [markdown]
# __Popularity (babies per million)__

# %%
df.groupby(["Year", "Gender"]).Count.sum()
# Out:
# Year  Gender
# 1880  F           90994
#       M          110490
# 1881  F           91953
#       M          100735
# 1882  F          107847
#                  ...
# 2021  M         1746499
# 2022  F         1636657
#       M         1741954
# 2023  F         1596022
#       M         1701224
# Name: Count, Length: 288, dtype: int64

# %% [markdown]
#  **To calculate the popularity of for example Mary we have to divide the tnumber of baby(Mary) to the total to get the reletive frequency or popularity**

# %%
7065 / 90994 * 1000000
# Out:
# 77642.48192188496

# %%
df.groupby(["Year", "Gender"]).Count.transform("sum")
# Out:
# 0            90994
# 1            90994
# 2            90994
# 3            90994
# 4            90994
#             ...
# 2117214    1701224
# 2117215    1701224
# 2117216    1701224
# 2117217    1701224
# 2117218    1701224
# Name: Count, Length: 2117219, dtype: int64

# %%
df.Count.div(df.groupby(["Year", "Gender"]).Count.transform("sum"))*1000000
# Out:
# 0         77642
# 1         28617
# 2         22012
# 3         21309
# 4         19188
#            ...
# 2117214       3
# 2117215       3
# 2117216       3
# 2117217       3
# 2117218       3
# Name: Count, Length: 2117219, dtype: float64

# %% [markdown]
# **we create popularity colum**

# %%
df["Popularity"] = df.Count.div(df.groupby(["Year", "Gender"]).Count.transform("sum"))*1000000

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity
# 0        1880       Mary      F   7065       77642
# 1        1880       Anna      F   2604       28617
# 2        1880       Emma      F   2003       22012
# 3        1880  Elizabeth      F   1939       21309
# 4        1880     Minnie      F   1746       19188
# ...       ...        ...    ...    ...         ...
# 2117214  2023      Zyell      M      5           3
# 2117215  2023       Zyen      M      5           3
# 2117216  2023     Zymirr      M      5           3
# 2117217  2023     Zyquan      M      5           3
# 2117218  2023      Zyrin      M      5           3
#
# [2117219 rows x 5 columns]

# %% [markdown]
# **Rank**

# %%
df.groupby(["Year", "Gender"])['Count'].rank(ascending=False)
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#            ...
# 2117214   13170
# 2117215   13170
# 2117216   13170
# 2117217   13170
# 2117218   13170
# Name: Count, Length: 2117219, dtype: float64

# %%
df["Rank"] =  df.groupby(["Year", "Gender"])['Count'].rank(ascending=False)

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity  Rank
# 0        1880       Mary      F   7065       77642     1
# 1        1880       Anna      F   2604       28617     2
# 2        1880       Emma      F   2003       22012     3
# 3        1880  Elizabeth      F   1939       21309     4
# 4        1880     Minnie      F   1746       19188     5
# ...       ...        ...    ...    ...         ...   ...
# 2117214  2023      Zyell      M      5           3 13170
# 2117215  2023       Zyen      M      5           3 13170
# 2117216  2023     Zymirr      M      5           3 13170
# 2117217  2023     Zyquan      M      5           3 13170
# 2117218  2023      Zyrin      M      5           3 13170
#
# [2117219 rows x 6 columns]

# %%
 df[(df.Year == 2023) & (df.Gender == "M")].head(60)#60 most popular name
# Out:
#          Year         Name Gender  Count  Popularity  Rank
# 2103070  2023         Liam      M  20802       12228     1
# 2103071  2023         Noah      M  18995       11165     2
# 2103072  2023       Oliver      M  14741        8665     3
# 2103073  2023        James      M  11670        6860     4
# 2103074  2023       Elijah      M  11452        6732     5
# 2103075  2023        Mateo      M  11229        6601     6
# 2103076  2023     Theodore      M  11041        6490     7
# 2103077  2023        Henry      M  10941        6431     8
# 2103078  2023        Lucas      M  10842        6373     9
# 2103079  2023      William      M  10598        6230    10
# 2103080  2023     Benjamin      M  10172        5979    11
# 2103081  2023         Levi      M   9347        5494    12
# 2103082  2023    Sebastian      M   8865        5211    13
# 2103083  2023         Jack      M   8683        5104    14
# 2103084  2023         Ezra      M   8437        4959    15
# ...

# %%
df[(df.Year == 2023) & (df.Gender == "M")].Popularity.sum()
# Out:
# 1000000.0

# %% [markdown]
#  ## Visualizing Name Trends over Time

# %%
mary = df[(df.Name == "Mary") & (df.Gender == "F")]
mary.tail(60)
# Out:
#          Year  Name Gender  Count  Popularity  Rank
# 621146   1964  Mary      F  40984       21629     2
# 633544   1965  Mary      F  34273       19417     2
# 645503   1966  Mary      F  28888       17072     3
# 657666   1967  Mary      F  25320       15336     4
# 670071   1968  Mary      F  21721       13242     6
# 683016   1969  Mary      F  19850       11767     8
# 696768   1970  Mary      F  19203       10985     9
# 711552   1971  Mary      F  16701       10038     9
# 726859   1972  Mary      F  13758        9044    13
# 742275   1973  Mary      F  12313        8444    14
# 757957   1974  Mary      F  11741        8001    13
# 774213   1975  Mary      F  10969        7524    19
# 791169   1976  Mary      F  10319        7043    22
# 808573   1977  Mary      F  10654        6949    21
# 826764   1978  Mary      F  10039        6553    24
# 844997   1979  Mary      F  10556        6576    24
# 864039   1980  Mary      F  11474        6910    25
# ...

# %% [markdown]
# **here we can see that over time  popularity of the name Mary decresed**

# %%
fig, ax1 = plt.subplots(figsize = (12, 8))
ax1.bar(x = mary.Year, height= mary.Popularity, label = "Popularity")
ax2 = ax1.twinx()
ax2.plot(mary.Year, mary.Rank, color = "red", label = "Rank")
ax1.set_xlabel("Year", fontsize = 15)
ax1.set_ylabel("Babies per million", fontsize = 15)
ax2.set_ylabel("Rank", fontsize = 15)
ax1.set_title("Mary", fontsize = 18)
ax1.tick_params(labelsize = 12)
ax2.tick_params(labelsize = 12)
ax1.legend(loc = 2, fontsize = 15)
ax2.legend(loc = 1, fontsize = 15)
plt.show()

# %%
def plot_name(name, gender, crit = "Popularity"):
    data = df.loc[(df.Name == name) & (df.Gender == gender), ["Name", "Gender", "Year", "Rank", crit]]
    data = data.set_index("Year")
    
    fig, ax1 = plt.subplots(figsize = (12, 8))
    ax1.bar(x = data.index, height= data[crit], label = crit)
    ax2 = ax1.twinx()
    ax2.plot(data.index, data.Rank, color = "red", label = "Rank")
    ax1.set_xlabel("Year", fontsize = 15)
    ax1.set_ylabel(crit, fontsize = 15)
    ax2.set_ylabel("Rank", fontsize = 15)
    ax1.set_title(name, fontsize = 18)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.legend(loc = 2, fontsize = 15)
    ax2.legend(loc = 1, fontsize = 15)
    plt.show()

# %%
plot_name("Mary", "F")

# %%
plot_name("Mary", "F", crit = "Count")

# %%
plot_name("Hannah", "F", crit = "Count")

# %%
plot_name("Liana", "F", crit = "Popularity")

# %%
df[df['Name']=='Liana']
# Out:
#          Year   Name Gender  Count  Popularity  Rank
# 269345   1929  Liana      F      6           5  4311
# 326063   1935  Liana      F      5           5  4548
# 368672   1940  Liana      F     13          11  2360
# 378033   1941  Liana      F     11           9  2756
# 388741   1942  Liana      F      6           4  4372
# ...       ...    ...    ...    ...         ...   ...
# 1958556  2019  Liana      F    670         400   466
# 1990677  2020  Liana      F    668         414   462
# 2022174  2021  Liana      F    774         472   410
# 2053944  2022  Liana      F    698         426   450
# 2086015  2023  Liana      F    638         400   479
#
# [86 rows x 6 columns]

# %%
df[df['Name']=='Hannah']
# Out:
#          Year    Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff
# 96       1880  Hannah      F    221        2429    96       NaN       NaN
# 2102     1881  Hannah      F    196        2132   103      2429      -297
# 4039     1882  Hannah      F    214        1984   106      2132      -147
# 6171     1883  Hannah      F    209        1861   110      1984      -124
# 8247     1884  Hannah      F    275        2131   104      1861       271
# ...       ...     ...    ...    ...         ...   ...       ...       ...
# 2021809  2021  Hannah      F   4586        2799    44      3074      -275
# 2052201  2021  Hannah      M      5           3 13107         3        -1
# 2053541  2022  Hannah      F   4478        2736    47      2799       -63
# 2081388  2022  Hannah      M      7           4 10329         3         1
# 2085584  2023  Hannah      F   4102        2570    48      2736      -166
#
# [187 rows x 8 columns]

# %%
m_evergreen
# Out:
#       Name  Count_2023  Count_1880
# 0    James       11670        5927
# 1    Henry       10941        2444
# 2  William       10598        9532
# 3   Samuel        7973        1024

# %%
for name in m_evergreen.Name:
    plot_name(name, "M", crit = "Popularity")

# %%
for name in f_evergreen.Name:
    plot_name(name, "F", crit = "Popularity")

# %%
df[df['Name']=='Elham']
# Out:
#          Year   Name Gender  Count  Popularity  Rank
# 765916   1974  Elham      F      6           4  8226
# 831485   1978  Elham      F     14           9  4804
# 850150   1979  Elham      F     13           8  5260
# 869331   1980  Elham      F     13           8  5394
# 891839   1981  Elham      F      7           4  8618
# 912506   1982  Elham      F      6           4  9876
# 930146   1983  Elham      F      8           5  7677
# 950479   1984  Elham      F      7           4  8647
# 987965   1986  Elham      F     11           6  6383
# 1009279  1987  Elham      F     10           6  7070
# 1034498  1988  Elham      F      6           3 11092
# 1053731  1989  Elham      F     10           5  7742
# 1076486  1990  Elham      F     13           7  6666
# 1105238  1991  Elham      F      7           4 10889
# 1133679  1992  Elham      F      5           3 14464
# 1153420  1993  Elham      F     10           6  8385
# 1259719  1997  Elham      F      8           5 10318
# ...

# %%
df[df['Name']=='Saeed']
# Out:
#          Year   Name Gender  Count  Popularity  Rank
# 682896   1968  Saeed      M      5           3  4440
# 696625   1969  Saeed      M      5           3  4724
# 754902   1973  Saeed      M     13           8  2786
# 770732   1974  Saeed      M     16          10  2504
# 787002   1975  Saeed      M     21          13  2169
# 805500   1976  Saeed      M     11           7  3366
# 822642   1977  Saeed      M     16          10  2726
# 840474   1978  Saeed      M     21          13  2242
# 859698   1979  Saeed      M     17          10  2722
# 877865   1980  Saeed      M     35          20  1676
# 898064   1981  Saeed      M     21          12  2377
# 918233   1982  Saeed      M     16           9  2900
# 938308   1983  Saeed      M     12           7  3519
# 957658   1984  Saeed      M     13           7  3362
# 976432   1985  Saeed      M     23          12  2325
# 997274   1986  Saeed      M     19          10  2730
# 1018056  1987  Saeed      M     23          12  2434
# ...

# %% [markdown]
# ## Why does a Name´s Popularity suddenly change? (Part 1)

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity  Rank
# 0        1880       Mary      F   7065       77642     1
# 1        1880       Anna      F   2604       28617     2
# 2        1880       Emma      F   2003       22012     3
# 3        1880  Elizabeth      F   1939       21309     4
# 4        1880     Minnie      F   1746       19188     5
# ...       ...        ...    ...    ...         ...   ...
# 2117214  2023      Zyell      M      5           3 13170
# 2117215  2023       Zyen      M      5           3 13170
# 2117216  2023     Zymirr      M      5           3 13170
# 2117217  2023     Zyquan      M      5           3 13170
# 2117218  2023      Zyrin      M      5           3 13170
#
# [2117219 rows x 6 columns]

# %%
df.loc[(df.Name == "Mary") & (df.Gender == "F"), "Popularity"]#.shift()
# Out:
# 0         77642
# 2000      75245
# 3934      75551
# 6061      71332
# 8145      71439
#            ...
# 1958215    1334
# 1990338    1378
# 2021897    1280
# 2053628    1292
# 2085671    1292
# Name: Popularity, Length: 144, dtype: float64

# %%
df["Pop_lag1"] = df.groupby(["Name", "Gender"]).Popularity.shift()

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity  Rank  Pop_lag1
# 0        1880       Mary      F   7065       77642     1       NaN
# 1        1880       Anna      F   2604       28617     2       NaN
# 2        1880       Emma      F   2003       22012     3       NaN
# 3        1880  Elizabeth      F   1939       21309     4       NaN
# 4        1880     Minnie      F   1746       19188     5       NaN
# ...       ...        ...    ...    ...         ...   ...       ...
# 2117214  2023      Zyell      M      5           3 13170         3
# 2117215  2023       Zyen      M      5           3 13170         6
# 2117216  2023     Zymirr      M      5           3 13170       NaN
# 2117217  2023     Zyquan      M      5           3 13170         4
# 2117218  2023      Zyrin      M      5           3 13170         3
#
# [2117219 rows x 7 columns]

# %% [markdown]
# **for year 1800  we have misssing value beacause we do not have information in 1799**

# %%
df[df.Name == "Hannah"]
# Out:
#          Year    Name Gender  Count  Popularity  Rank  Pop_lag1
# 96       1880  Hannah      F    221        2429    96       NaN
# 2102     1881  Hannah      F    196        2132   103      2429
# 4039     1882  Hannah      F    214        1984   106      2132
# 6171     1883  Hannah      F    209        1861   110      1984
# 8247     1884  Hannah      F    275        2131   104      1861
# ...       ...     ...    ...    ...         ...   ...       ...
# 2021809  2021  Hannah      F   4586        2799    44      3074
# 2052201  2021  Hannah      M      5           3 13107         3
# 2053541  2022  Hannah      F   4478        2736    47      2799
# 2081388  2022  Hannah      M      7           4 10329         3
# 2085584  2023  Hannah      F   4102        2570    48      2736
#
# [187 rows x 7 columns]

# %%
df.loc[(df.Year > 1880) & (df.Pop_lag1.isna()), "Pop_lag1"] = 0

# %%
df[df.Name == "Hannah"]
# Out:
#          Year    Name Gender  Count  Popularity  Rank  Pop_lag1
# 96       1880  Hannah      F    221        2429    96       NaN
# 2102     1881  Hannah      F    196        2132   103      2429
# 4039     1882  Hannah      F    214        1984   106      2132
# 6171     1883  Hannah      F    209        1861   110      1984
# 8247     1884  Hannah      F    275        2131   104      1861
# ...       ...     ...    ...    ...         ...   ...       ...
# 2021809  2021  Hannah      F   4586        2799    44      3074
# 2052201  2021  Hannah      M      5           3 13107         3
# 2053541  2022  Hannah      F   4478        2736    47      2799
# 2081388  2022  Hannah      M      7           4 10329         3
# 2085584  2023  Hannah      F   4102        2570    48      2736
#
# [187 rows x 7 columns]

# %%
df["Pop_diff"] = df.Popularity - df.Pop_lag1

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff
# 0        1880       Mary      F   7065       77642     1       NaN       NaN
# 1        1880       Anna      F   2604       28617     2       NaN       NaN
# 2        1880       Emma      F   2003       22012     3       NaN       NaN
# 3        1880  Elizabeth      F   1939       21309     4       NaN       NaN
# 4        1880     Minnie      F   1746       19188     5       NaN       NaN
# ...       ...        ...    ...    ...         ...   ...       ...       ...
# 2117214  2023      Zyell      M      5           3 13170         3        -0
# 2117215  2023       Zyen      M      5           3 13170         6        -3
# 2117216  2023     Zymirr      M      5           3 13170         0         3
# 2117217  2023     Zyquan      M      5           3 13170         4        -1
# 2117218  2023      Zyrin      M      5           3 13170         3        -1
#
# [2117219 rows x 8 columns]

# %%
df2 = df[df.Year >= 1900].copy()

# %%
df2.nlargest(20, "Pop_diff")
# Out:
#          Year      Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff
# 431064   1947     Linda      F  99693       56237     1     33545     22691
# 321476   1935   Shirley      F  42364       40402     2     21874     18528
# 922655   1983    Ashley      F  33293       19929     4      8773     11156
# 711544   1971  Jennifer      F  56770       34121     1     26400      7720
# 726847   1972  Jennifer      F  63605       41812     1     34121      7692
# 312299   1934   Shirley      F  22841       21874     4     14207      7667
# 645504   1966  Michelle      F  27158       16050     4      9186      6863
# 752071   1973     Jason      M  46675       29946     3     23084      6862
# 844976   1979    Amanda      F  31926       19888     3     13394      6494
# 696760   1970  Jennifer      F  46151       26400     1     19979      6421
# 472256   1951   Deborah      F  42053       23352     4     16964      6387
# ...

# %% [markdown]
# **here we can see that the popularity of name Linda and Shirley,... have incresed between 1940 and 1970  and then again decresed**

# %%
plot_name("Linda", "F")

# %%
plot_name("Linda", "F")

# %%
df2.nsmallest(20, "Pop_diff")
# Out:
#          Year      Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff
# 339409   1937   Shirley      F  26823       25209     4     33797     -8588
# 330514   1936   Shirley      F  35162       33797     2     40402     -6605
# 461947   1950     Linda      F  80430       46951     1     53199     -6248
# 472253   1951     Linda      F  73982       41081     1     46951     -5870
# 961586   1985  Jennifer      F  42658       24790     3     30030     -5240
# 482719   1952     Linda      F  67080       36175     1     41081     -4907
# 696761   1970      Lisa      F  38965       22290     2     26691     -4401
# 437172   1947   Richard      M  58534       31994     5     36250     -4255
# 537666   1957   Deborah      F  40095       19608     6     23827     -4219
# 504202   1954     Linda      F  55375       28516     2     32574     -4058
# 808555   1977       Amy      F  26731       17435     3     21390     -3954
# ...

# %%
df[df['Year']==2023][['Name','Rank']].head(20)
# Out:
#               Name  Rank
# 2085537     Olivia     1
# 2085538       Emma     2
# 2085539  Charlotte     3
# 2085540     Amelia     4
# 2085541     Sophia     5
# 2085542        Mia     6
# 2085543   Isabella     7
# 2085544        Ava     8
# 2085545     Evelyn     9
# 2085546       Luna    10
# 2085547     Harper    11
# 2085548      Sofia    12
# 2085549     Camila    13
# 2085550    Eleanor    14
# 2085551  Elizabeth    15
# 2085552     Violet    16
# 2085553   Scarlett    17
# 2085554      Emily    18
# 2085555      Hazel    18
# 2085556       Lily    20

# %%
df2["%change"] = df2.Popularity.div(df2.Pop_lag1).sub(1).mul(100)#percent of changes

# %%
df2
# Out:
#          Year      Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff  \
# 52264    1900      Mary      F  16705       55723     1     56527      -803
# 52265    1900     Helen      F   6342       21155     2     21663      -508
# 52266    1900      Anna      F   6114       20395     3     21951     -1556
# 52267    1900  Margaret      F   5304       17693     4     18234      -542
# 52268    1900      Ruth      F   4765       15895     5     16788      -893
# ...       ...       ...    ...    ...         ...   ...       ...       ...
# 2117214  2023     Zyell      M      5           3 13170         3        -0
# 2117215  2023      Zyen      M      5           3 13170         6        -3
# 2117216  2023    Zymirr      M      5           3 13170         0         3
# 2117217  2023    Zyquan      M      5           3 13170         4        -1
# 2117218  2023     Zyrin      M      5           3 13170         3        -1
#
#          %change
# 52264         -1
# 52265         -2
# ...

# %%
df2[df2.Pop_lag1 > 1000].nsmallest(20, "%change")# most negative percentage changes
# Out:
#          Year      Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff  \
# 758251   1974    Katina      F    766         522   307      1697     -1175
# 1120175  1992     Iesha      F    581         315   432      1011      -696
# 1424051  2003   Ashanti      F    962         527   325      1640     -1113
# 515393   1955    Marian      F   1499         767   208      2067     -1300
# 175398   1920   Woodrow      M    774         727   183      1845     -1117
# 1145436  1993   Hillary      F   1064         588   261      1367      -779
# 1249983  1997    Shania      F    861         495   331      1048      -553
# 54561    1900     Dewey      M    345        2293    75      4698     -2405
# 275071   1930  Jeannine      F    593         527   258      1060      -533
# 981848   1986    Sheena      F   1573         917   173      1779      -862
# 71825    1905     Alton      M    164        1240   135      2357     -1118
# ...

# %%
plot_name("Katina", "F")

# %%
plot_name("Iesha", "F")
